# %% [markdown]
# ## Assignement II: Neural Networks

# %% [markdown]
# __Date given: April 16th__
#
# __Date due: April 29th__
#
# __ Total: 21 pts__

# %% [markdown]
# In this assignment you will get a chance to apply what we learned on neural networks. We will start by discussing the notion of overfitting. This will give you the opportunity to apply your knowledge on neural networks with the models from scikit-learn (which are easier to take in hand) first (Exercises 1.1 and 1.2). We will then smoothly transition to the keras models by first (approximately) duplicating the construction from scikit learn in keras. Finally, you will be given the opporunity to code a (convolutional) network in keras to discriminate between pictures of cats and dogs.

# %% [markdown]
# ### 1. Overfitting might be trickier than you think..

# %% [markdown]
# __1.1 (5pts) Overfitting the Iris dataset__
#
# As a first exercise, we will see that for some datasets, it might actually be quite difficult to overfit. For this, consider the Iris dataset below. Split your dataset into a training and test part (take 10% test set).
# You will learn a multi-layer perceptron on your training data.
# To visualize the evolution of the training and validation error, we will use the following trick:
#   - You will fit the MLP to your training data using a single iteration of adam (default solver) and set the parameter 'warm_start' to True (this means you reuse the previous weights as your initialization of the next training steps).
#   - Then we will embed this 'one step' training of the MLP into a outer for loop (set the number of outer iterations to lets say 200). Inside the loop, do you 1 step training (mlp.fit) of the MLP. After each training, compute the score on the training and test sets using the mpl.score function. Store the result in two vectors.
#   - After the for loop, plot the two vectors.
#
#
# Repeat your experiments for various sizes of the MLP hidden layer (for example 10, 100, 200, 500 and 1000). Plot the test and training error. What do you observe ? How do the two curves look with respect to each other? What is your intuition on why this is the case?

# %%
from sklearn import datasets
from sklearn.neural_network import MLPClassifier
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

iris = datasets.load_iris()

X = iris.data
Y = iris.target

X_train, X_test, Y_train, Y_test = train_test_split(iris.data, iris.target, test_size=0.1)
mlp = MLPClassifier(random_state=2, warm_start=True)

train_score = []
test_score = []

for i in range(200):
    mlp.fit(X_train, Y_train)
    train_score.append(mlp.score(X_train, Y_train))
    #print(mlp.score(X_train, Y_train))
    test_score.append(mlp.score(X_test, Y_test))
    #print(mlp.score(X_test, Y_test))


plt.plot(train_score, c='orange')
plt.plot(test_score, c="b")
plt.show()
# Out:
# //anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
mlp2 = MLPClassifier(hidden_layer_sizes=(10,),random_state=2, warm_start=True)

train_score2 = []
test_score2 = []

for i in range(200):
    mlp2.fit(X_train, Y_train)
    train_score2.append(mlp2.score(X_train, Y_train))
    #print(mlp.score(X_train, Y_train))
    test_score2.append(mlp2.score(X_test, Y_test))
    #print(mlp.score(X_test, Y_test))


plt.plot(train_score2, color='orange')
plt.plot(test_score2, color='b')
plt.show()
# Out:
# //anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
mlp3 = MLPClassifier(hidden_layer_sizes=(100,),random_state=2, warm_start=True)

train_score3 = []
test_score3 = []

for i in range(200):
    mlp3.fit(X_train, Y_train)
    train_score3.append(mlp3.score(X_train, Y_train))
    test_score3.append(mlp3.score(X_test, Y_test))


plt.plot(train_score3, color='orange')
plt.plot(test_score3, color='b')
plt.show()
# Out:
# //anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
mlp4 = MLPClassifier(hidden_layer_sizes=(200,),random_state=2, warm_start=True)

train_score4 = []
test_score4 = []

for i in range(200):
    mlp4.fit(X_train, Y_train)
    train_score4.append(mlp4.score(X_train, Y_train))
    test_score4.append(mlp4.score(X_test, Y_test))


plt.plot(train_score4, color='orange')
plt.plot(test_score4, color='b')
plt.show()
# Out:
# //anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
mlp5 = MLPClassifier(hidden_layer_sizes=(500,),random_state=2, warm_start=True)

train_score5 = []
test_score5 = []

for i in range(200):
    mlp5.fit(X_train, Y_train)
    train_score5.append(mlp5.score(X_train, Y_train))
    test_score5.append(mlp5.score(X_test, Y_test))


plt.plot(train_score5, color='orange')
plt.plot(test_score5, color='b')
plt.show()
# Out:
# //anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
mlp6 = MLPClassifier(hidden_layer_sizes=(1000,),random_state=2, warm_start=True)

train_score6 = []
test_score6 = []

for i in range(200):
    mlp6.fit(X_train, Y_train)
    train_score6.append(mlp6.score(X_train, Y_train))
    test_score6.append(mlp6.score(X_test, Y_test))


plt.plot(train_score6, color='orange')
plt.plot(test_score6, color='b')
plt.show()
# Out:
# //anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# Q: Repeat your experiments for various sizes of the MLP hidden layer (for example 10, 100, 200, 500 and 1000). Plot the test and training error. What do you observe ? How do the two curves look with respect to each other? What is your intuition on why this is the case?
#
# A: The score is higher with the layers getting larger but it does not improve overtime with the training since we see straight lines in both 10 layer and 1000 layer graph, coule be meaning that these two constructions do not work well. In addition, the test scores for all are plotting as a straight, indicating that the model is overfit.

# %% [markdown]
# __1.2 Overfitting the Iris dataset: continued (3pts)__ To get some more intuition on why we observe such a behavior on the Iris dataset, we will use another classification algorithm: 1 nearest neighbor. One nearest neighbor algorithm simply defines the class of a point from the test set as the class of the point that is the closest to that point in the training set. compute the validation (i.e test) error for a 1 nearest neighbor classifier.
#
#  - What error do you get?
#  - In your opinion, is the 1NN algorithm overfitting?
#  - What does 1NN tells you on the Iris dataset?

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

oneNN = KNeighborsClassifier(n_neighbors=1).fit(X_train, Y_train)
#distances, indices = oneNN.kneighbors(X_train, Y_train)

pred = oneNN.predict(X_test)
error = np.mean(pred!= Y_test)
print(accuracy_score(Y_test, pred))
print(error)
# Out:
# 0.9333333333333333
# 0.06666666666666667

# %% [markdown]
# A: The error I get is 0.0666666667. Yes, the 1NN algorithm is overfitting since the 1 neighbor gives a non-smooth decision surface. In addition, the errors is really small even with this algorithm, also indicating that this is a overfit. This result tells us that Iris dataset is already well-classified in that even with 1NN algorithm, it has a high accuracy score.

# %% [markdown]
# __1.3. (7points) From Overfitting Iris to overfitting MNIST.__
#
#
# In this third exercise, we will use a more advanced dataset in the hope of finally witnessing some clear overfitting. Load the MNIST dataset using the lines below

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier

print(__doc__)

# Load data from https://www.openml.org/d/554
X, Y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X / 255.
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# As a warm up, we will again use Scikit learn to design a neural network. When considering neural networks, Scikit learn is in general much less powerful than Keras. However, it is much easier to use. Split the MNIST dataset into a training and a test part (again you can take 10% test samples). Then train a MLP on the training set. As before embed the training in a for loop to keep track of both training and test errors.
#
# - Use a single (200 neurons) hidden layers,
# - Set the regularization parameter to 0.
# - Take a .1 or smaller learning rate and train with the stochastic gradient algorithm
#
# Repeat the experiments for a hidden layers of size (5,), (10,), (50,), (100,) as well as (10,2), (50,2), (100,2) and comment your results.

# %%
from sklearn.neural_network import MLPClassifier
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

#print(np.shape(X))
#print(np.shape(Y))

X_train3, X_test3, Y_train3, Y_test3 = train_test_split(X, Y, test_size=0.1) #add random_state parameter
mlp31 = MLPClassifier(hidden_layer_sizes=(200,), solver='sgd', alpha=0, random_state=2, warm_start=True, learning_rate_init=0.1)

train_s3 = []
test_s3 = []

for i in range(200):
    mlp31.fit(X_train3, Y_train3)
    train_s3.append(mlp31.score(X_train3, Y_train3))
    test_s3.append(mlp31.score(X_test3, Y_test3))


plt.plot(train_s3)
plt.plot(test_s3)
plt.show()

# %%
mlp32 = MLPClassifier(hidden_layer_sizes=(5,), solver='sgd', alpha=0, random_state=2, warm_start=True, learning_rate_init=0.1)

train_s3 = []
test_s3 = []

for i in range(200):
    mlp32.fit(X_train3, Y_train3)
    train_s3.append(mlp32.score(X_train3, Y_train3))
    test_s3.append(mlp32.score(X_test3, Y_test3))


plt.plot(train_s3)
plt.plot(test_s3)
plt.show()

# %%
mlp33 = MLPClassifier(hidden_layer_sizes=(10,), solver='sgd', alpha=0, random_state=2, warm_start=True, learning_rate_init=0.1)

train_s31 = []
test_s31 = []

for i in range(200):
    mlp33.fit(X_train3, Y_train3)
    train_s31.append(mlp33.score(X_train3, Y_train3))
    test_s31.append(mlp33.score(X_test3, Y_test3))


plt.plot(train_s31)
plt.plot(test_s31)
plt.show()

# %%
mlp34 = MLPClassifier(hidden_layer_sizes=(50,), solver='sgd', alpha=0, random_state=2, warm_start=True, learning_rate_init=0.1)

train_s3 = []
test_s3 = []

for i in range(200):
    mlp34.fit(X_train3, Y_train3)
    train_s3.append(mlp34.score(X_train3, Y_train3))
    test_s3.append(mlp34.score(X_test3, Y_test3))


plt.plot(train_s3)
plt.plot(test_s3)
plt.show()

# %%
mlp35 = MLPClassifier(hidden_layer_sizes=(100,), solver='sgd', alpha=0, random_state=2, warm_start=True, learning_rate_init=0.1)

train_s3 = []
test_s3 = []

for i in range(200):
    mlp35.fit(X_train3, Y_train3)
    train_s3.append(mlp35.score(X_train3, Y_train3))
    test_s3.append(mlp35.score(X_test3, Y_test3))


plt.plot(train_s3)
plt.plot(test_s3)
plt.show()

# %%
mlp36 = MLPClassifier(hidden_layer_sizes=(10,2), solver='sgd', alpha=0, random_state=2, warm_start=True, learning_rate_init=0.1)

train_s3 = []
test_s3 = []

for i in range(200):
    mlp36.fit(X_train3, Y_train3)
    train_s3.append(mlp36.score(X_train3, Y_train3))
    test_s3.append(mlp36.score(X_test3, Y_test3))


plt.plot(train_s3)
plt.plot(test_s3)
plt.show()

# %%
mlp37 = MLPClassifier(hidden_layer_sizes=(50,2), solver='sgd', alpha=0, random_state=2, warm_start=True, learning_rate_init=0.1)

train_s3 = []
test_s3 = []

for i in range(200):
    mlp37.fit(X_train3, Y_train3)
    train_s3.append(mlp37.score(X_train3, Y_train3))
    test_s3.append(mlp37.score(X_test3, Y_test3))


plt.plot(train_s3)
plt.plot(test_s3)
plt.show()

# %%
mlp38 = MLPClassifier(hidden_layer_sizes=(100,2), solver='sgd', alpha=0, random_state=2, warm_start=True, learning_rate_init=0.1)

train_s3 = []
test_s3 = []

for i in range(200):
    mlp38.fit(X_train3, Y_train3)
    train_s3.append(mlp38.score(X_train3, Y_train3))
    test_s3.append(mlp38.score(X_test3, Y_test3))


plt.plot(train_s3)
plt.plot(test_s3)
plt.show()

# %% [markdown]
# Result Comment:
# For the single neuron layers constructions of MLP, the shapes of both lines for training and testing are similar and there were fewer steep drops of score when increasing the number of layers. However, we also noticed two straight lines for layer 5 and 10, mainly because they might not be sufficient enough to complete the classification.
# With the 2 neuron layers constructions of MLP, we see opposite directions of training and testing scores, and extermely low scores results as well. Indicating these constructions are not suitable.

# %% [markdown]
# The Mnist dataset is relatively smooth. Moreover, Scikit-learn is not really optimized to deal with large neural networks. To highlight the change in dynamics related to overfiting, it is better to turn to Keras. A good approach to familiarize with Keras is to first try to replicate a given model from scikit learn.
#
# Try to replicate the model you used from Scikit learn by using Keras. (focus only on the one hidden layer model). You will need to transform the MNIST labels into their corresponding binary representation (check np_utils.to_categorical)
#
#
# Training a model in keras is done through 3 steps:
#
# - build the model
# - define the training framework (look at compile)
# - fit the model
#
#
# __Hint 1__: check the documentation of scikit learn on the MLP (https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier)
#
# __Hint 2__: On top of the hidden layer, you will have to finish your keras network with a dense layer whose number of units equals the number of classes in MNIST (i.e each output corresponds to the probability of having a given number and you thus need 10 outputs). The activation function for that last layer should be the softmax (https://fr.wikipedia.org/wiki/Fonction_softmax) as it returns class probabilities.
#
#
#
# Use the same manoeuvre as for Scikit-learn to monitor both the training and the test errors (play with the epochs parameter).

# %%
#import libraries
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.preprocessing import MinMaxScaler, scale, StandardScaler, Normalizer

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import regularizers
from keras.optimizers import SGD
import keras

from keras.layers import Dense # Dense layers are "fully connected" layers
from keras.models import Sequential # Documentation: https://keras.io/models/sequential/

image_size = 784 # 28*28
num_classes = 10 # ten unique digits


bin_Y = keras.utils.to_categorical(Y, num_classes=10, dtype='float32')
X_train4, X_test4, Y_train4, Y_test4 = train_test_split(X, bin_Y, test_size=0.1)

model = Sequential()
model.add(Dense(32, activation='sigmoid', input_shape=(image_size,)))#One hidden layer, MLP uses 'relu' activation
model.add(Dense(10, activation='softmax'))#Final Output Layer

model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train4, Y_train4, batch_size=128, epochs=5, verbose=False, validation_split=.1)
loss, accuracy  = model.evaluate(X_test4, Y_test4, verbose=False)

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')
plt.show()

print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
# Out:
# Test loss: 1.02
# Test accuracy: 0.818

# %% [markdown]
# ### 2. (6 pts) Cats and Dogs
#
# Now that you are a little more comfortable with Keras, you will get to code and apply a neural network to some real dataset.
#
# You get all the points for this question if you can build the network, train it and apply it to the test set with reasonable results.
# You get 2 bonus points if you can score better than 85% on the test (or any given randomly slected subset)
# You get 1 more bonus point if you get the best scores when I test your model with any subset of images from the test set

# %% [markdown]
# Now that you got familiarized with Keras, we can focus on a funnier instance of classification. In this exercise, we will learn to discriminate between pictures of cats and dogs

# %% [markdown]
# Go to kaggle and download the Microsoft dogs vs cats dataset: https://www.kaggle.com/c/dogs-vs-cats/rules

# %% [markdown]
# __2.1.__ First write a function that runs through all the images and find the minimum size. You can start with the snippet below. To apply a neural network to our dataset, we will first need to

# %%
# put your code here. You can make use of the lines below to load the images

path = '/Users/gaoyijia/Documents/2019MachineLearning/Assignement2/dogs-vs-cats/train'
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

minSize = (0,0)

for p in os.listdir(path):
    category = p.split(".")[0]
    img_array = cv2.imread(os.path.join(path,p),cv2.IMREAD_GRAYSCALE)
    print(np.shape(img_array))
    new_img_array = cv2.resize(img_array, dsize=(80, 80))
    plt.imshow(new_img_array,cmap="gray")
    plt.show()
    break
# Out:
# (500, 380)

# %%
minSize = (500000,500000)

for p in os.listdir(path):
    category = p.split(".")[0]
    img_array = cv2.imread(os.path.join(path,p),cv2.IMREAD_GRAYSCALE)
    if img_array.shape < minSize:
        minSize = img_array.shape
        plt.imshow(img_array,cmap="gray")

print(minSize)
# Out:
# (32, 60)

# %% [markdown]
# __2.2__ Now write a function that runs through the images and (Hint: use the functions resize from cv2 and append from numpy) build a matrix storing the images after setting them to the appropriate minimum size (hint check the function 'cv2.resize')
#
# Dont forget to normalize the data (X = X/255.0)

# %%
data=[]
label=[]

convert = lambda category : int(category == 'dog')
for p in os.listdir(path):
    category = p.split(".")[0]
    category = convert(category)
    #print(category)
    label.append(category)
    img_array = cv2.imread(os.path.join(path,p),cv2.IMREAD_GRAYSCALE)
    new_img_array = cv2.resize(img_array, dsize=(minSize[0],minSize[0]))
    data.append(new_img_array)

print(np.shape(data))
print(np.shape(label))

data = np.array(data).reshape(-1,32,32,1)
data = np.array(data) / 255
# Out:
# (25000, 32, 32)
# (25000,)

# %%
path2 = '/Users/gaoyijia/Documents/2019MachineLearning/Assignement2/dogs-vs-cats/test1'

test_data=[]
test_label=[]

convert = lambda category : int(category == 'dog')
for p in os.listdir(path2):
    category = p.split(".")[0]
    category = convert(category)
    test_label.append(category)
    img_array = cv2.imread(os.path.join(path2,p),cv2.IMREAD_GRAYSCALE)
    new_img_array = cv2.resize(img_array, dsize=(minSize[0],minSize[0]))
    test_data.append(new_img_array)

print(np.shape(test_data))
print(np.shape(test_label))

test_data = np.array(test_data)
test_data = test_data / 255.
# Out:
# (12500, 32, 32)
# (12500,)

# %%
convert = lambda category : int(category == 'dog')
for p in os.listdir(path):
    category = p.split(".")[0]
    img_array = cv2.imread(os.path.join(path,p),cv2.IMREAD_GRAYSCALE)
    new_img_array = cv2.resize(img_array, dsize=(minSize[0],minSize[0]))
    plt.imshow(new_img_array,cmap="gray")
    plt.show()
    break

# %% [markdown]
# __2.3.__ So far we have considered traditional Multilayer perceptrons. However, when dealing with images, it is usually much more interesting to use convolutional neural networks (see https://en.wikipedia.org/wiki/Convolutional_neural_network or http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf, Fig.2). convolution neural networks work by sliding a filter on the input image and computing local "averages". In the example below the input image is binary and the filter is made up of all 1. But in practical convolution neural networks, the network learns the green filter and the blue matrix represents our images
#
# The red image then represents the output to the filter (the sum of the product of the elements of the green filter by the elements of the image)

# %% [markdown]
# ![convolution1.gif](attachment:convolution1.gif)

# %% [markdown]
# As for MNIST, there are three steps that we need to follow
# - First we need to build the network
# - We then need to define the solver used
# - Finally we train the network
#
# We can build a simple convolutional Neural network as follows:
#     - Take the Sequential model (this is the conventional model)
#
# The architecture of a convolutional neural network usually involves 4 parts:
#
#    - Convolution
#    - Pooling
#    - Flattening
#    - Fully connected layer
#
# For the convolution part we will repeat __twice__ the following construction:
#
#    - Add a first 2D convolutional layer (see https://keras.io/layers/convolutional/) with 64 3 by 3 filters and Relu activation function
#
#    - To make the detection robust and to speed up the computation, a popular approach is to use MaxPooling (MaxPooling turns the output of the convolution layer into a reduced image by only retaining the max across a particular region). One intuition for maxPooling (given by Andrew Ng) is that if a feature (the ear of a cat/dog for example) is detected, is should be keps in the output (hence the max). Add a 2D maxPooling layer, after the convolutional layer, with 2 by 2 pooling windows
#
#
# Then, following the conventional CNN structure we Flatten the result (see model.add(Flatten())).
#
# Finally, we add a dense layer of 64 neurons with Relu activation function.
#
# To define the final output, you can add a simple dense layer with only one neuron. As we only have two classes defined by a binary variable, we will choose our activation function to be the sigmoid.

# %% [markdown]
# ![Maxpool.png](attachment:Maxpool.png)

# %%
# put the construction of the Keras network here
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Activation
from keras.optimizers import SGD
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
import keras

#le = LabelEncoder()
#label = le.fit_transform(label)
#labelBin = keras.utils.to_categorical(label)

input_shape=(minSize[0], minSize[0], 1)

model2 = Sequential()

model2.add(Conv2D(64, (3, 3), input_shape=input_shape))
model2.add(Activation("relu"))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(64, (3, 3)))
model2.add(Activation("relu"))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Flatten())
model2.add(Dense(64))
model2.add(Activation("relu"))
model2.add(Dropout(rate=0.5))
model2.add(Dense(1))
model2.add(Activation("sigmoid"))

# %% [markdown]
# Now that we have built the network, we need to define our training algorithm. This is done with a call to model.compile (see https://keras.io/getting-started/sequential-model-guide/#compilation)
#
# You can modify the parameters but to start, a good choice is to choose 'adam' as your solver, and the binary cross entropy as your loss. Also set metrics=['accuracy'] to keep track of the training error.

# %%
model2.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

model2.summary()
print(model2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 30, 30, 64)        640
# _________________________________________________________________
# activation_14 (Activation)   (None, 30, 30, 64)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                147520
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# _________________________________________________________________
# activation_17 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 185,153
# Trainable params: 185,153
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.sequential.Sequential object at 0x1a503d7748>

# %% [markdown]
# You are now ready to train your model using a call to the 'fit' function of this model. Again up to you if you want to modify the parameters but a good start can be to take 10 epochs and to take a batch of size about 30. Also check the 'validation_split' argument (https://keras.io/models/sequential/). This might give you an indication of how well your model is doing through training. You might also want to only consider a subset of the image when training as the data set is quite large.

# %%
subSize = 5000
dataS = data[:subSize]
#dataSub = np.expand_dims(dataS, -1)

dataSub = np.array(dataS).reshape(-1,32,32,1)

label = np.array(label)
labelSub = label[:subSize]


#testDataSub = test_data[:200]

history2 = model2.fit(dataSub, labelSub, epochs=15, batch_size=30, validation_split = 0.1)
#loss, accuracy  = model2.evaluate(X_test4, Y_test4)

#plt.plot(history.history['acc'])
#plt.plot(history.history['val_acc'])
#plt.title('model accuracy')
#plt.ylabel('accuracy')
#plt.xlabel('epoch')
#plt(history2)
#plt.legend(['training', 'validation'], loc='best')
#plt.show()

#print(f'Test loss: {loss:.3}')
#print(f'Test accuracy: {accuracy:.3}')
# Out:
# Train on 4500 samples, validate on 500 samples
# Epoch 1/15
# 4500/4500 [==============================] - 12s 3ms/step - loss: 0.6924 - acc: 0.5162 - val_loss: 0.6755 - val_acc: 0.5840
# Epoch 2/15
#  - ETA: 4s - loss: 0.6779 - acc: 0.5808
# Epoch 3/15
#  - ETA: 5s - loss: 0.6495 - acc: 0.6171
# Epoch 4/15
# 4500/4500 [==============================] - 10s 2ms/step - loss: 0.6210 - acc: 0.6638 - val_loss: 0.5944 - val_acc: 0.6700
# Epoch 5/15
# 4500/4500 [==============================] - 10s 2ms/step - loss: 0.5776 - acc: 0.7009 - val_loss: 0.5796 - val_acc: 0.7100
# Epoch 6/15
# 4500/4500 [==============================] - 10s 2ms/step - loss: 0.5459 - acc: 0.7276 - val_loss: 0.5880 - val_acc: 0.6820
# Epoch 7/15
# 4500/4500 [==============================] - 10s 2ms/step - loss: 0.5235 - acc: 0.7418 - val_loss: 0.5560 - val_acc: 0.7260
# Epoch 8/15
# 4500/4500 [==============================] - 10s 2ms/step - loss: 0.4972 - acc: 0.7687 - val_loss: 0.5720 - val_acc: 0.7120
# Epoch 9/15
#  - ETA: 2s - loss: 0.4663 - acc: 0.7801
# Epoch 10/15
# 4500/4500 [==============================] - 10s 2ms/step - loss: 0.4439 - acc: 0.7938 - val_loss: 0.5482 - val_acc: 0.7460
# Epoch 11/15
#  - ETA: 6s - loss: 0.4310 - acc: 0.8046
# Epoch 12/15
#  - ETA: 5s - loss: 0.3865 - acc: 0.8205
# Epoch 13/15
#  - ETA: 6s - loss: 0.3612 - acc: 0.8444
# Epoch 14/15
# 4500/4500 [==============================] - 10s 2ms/step - loss: 0.3382 - acc: 0.8489 - val_loss: 0.5872 - val_acc: 0.7360
# Epoch 15/15
# 4500/4500 [==============================] - 10s 2ms/step - loss: 0.3234 - acc: 0.8578 - val_loss: 0.6080 - val_acc: 0.7320

# %%
input_shape=(minSize[0], minSize[0], 1)

model3 = Sequential()

model3.add(Conv2D(64, 3, 3, border_mode='same', input_shape=input_shape,activation='relu'))
model3.add(Conv2D(64, 3, 3, border_mode='same',activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(64, 3, 3, border_mode='same',activation='relu'))
model3.add(Conv2D(64, 3, 3, border_mode='same',activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(128, 3, 3, border_mode='same', activation='relu'))
model3.add(Conv2D(128, 3, 3, border_mode='same',activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(256, 3, 3, border_mode='same', activation='relu'))
model3.add(Conv2D(256, 3, 3, border_mode='same', activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))

model3.add(Dense(1))
model3.add(Activation("sigmoid"))
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), input_shape=(32, 32, 1..., activation="relu", padding="same")`
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:18: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`

# %%
model3.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

model3.summary()
print(model3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        640
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# _________________________________________________________________
# activation_5 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,546,561
# Trainable params: 1,546,561
# Non-trainable params: 0
# _________________________________________________________________
# <keras.engine.sequential.Sequential object at 0x1a4edf56a0>

# %%
subSize = 2000
dataS2 = data[:subSize]
#dataSub = np.expand_dims(dataS, -1)

dataSub2 = np.array(dataS2).reshape(-1,32,32,1)

label = np.array(label)
labelSub2 = label[:subSize]

#testDataSub = test_data[:200]

#history3 = model3.fit(dataSub2, labelSub2, epochs=10, batch_size=30, validation_split = 0.1)
